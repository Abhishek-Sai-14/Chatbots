# %%
# %run train_chatbot.py
# Out:
# 145 documents
# 30 classes ['Aambal', 'Allen_solly', 'Bharath', 'Clappana_sweet', 'Crown', 'Kochi', 'Kollam', 'Krishna', 'Lekshmi', 'Lulu', 'Maha', 'Miss', 'Peter', 'Priya', 'Sangam', 'Sasthas', 'Thiruvanathapuram', 'Trends', 'about', 'bye', 'clappana', 'cloth_kochi', 'cloth_thiru', 'greeting', 'help', 'name', 'near', 'pickle', 'pothys', 'thanks']
# ...

# %%
# %run chatgui.py
# Out:
#  * Serving Flask app "chatgui" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
# 127.0.0.1 - - [04/Jun/2023 17:02:27] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Jun/2023 17:02:27] "GET /india.jpg HTTP/1.1" 404 -
# 127.0.0.1 - - [04/Jun/2023 17:02:29] "POST / HTTP/1.1" 302 -
# 127.0.0.1 - - [04/Jun/2023 17:02:29] "GET /userpage1 HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Jun/2023 17:02:29] "GET /static/hyderabad.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Jun/2023 17:02:29] "GET /static/blore.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Jun/2023 17:02:29] "GET /static/mumbai.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Jun/2023 17:02:29] "GET /static/vizag.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [04/Jun/2023 17:02:29] "GET /static/trivendram.jpg HTTP/1.1" 200 -
# ...
