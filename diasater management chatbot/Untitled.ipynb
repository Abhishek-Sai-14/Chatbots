# %%
# %run train_chatbot.py
# Out:
# 55 documents
# 16 classes ['Alapad', 'Azheekal', 'Parakkadavu', 'about', 'alert_kochi', 'bye', 'greeting', 'kerala', 'kochi_contact', 'kochi_duration', 'kochi_evacuation', 'kochi_relief', 'kochi_road', 'name', 'risk', 'thanks']
# ...

# %%
# %run chatgui.py
# Out:
#  * Serving Flask app "chatgui" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
# 127.0.0.1 - - [10/Jun/2023 20:41:48] "GET /userpage2 HTTP/1.1" 200 -
# Kerala
# 1/1 [==============================] - 0s 184ms/step
# 127.0.0.1 - - [10/Jun/2023 20:41:57] "GET /get?msg=Kerala HTTP/1.1" 200 -
# [{'intent': 'kerala', 'probability': '0.9993137'}]
# kerala
# ...
